# %% [markdown]
# # Data Science Capstone Project

# %% [markdown]
# ### This notebook is contains the IBM Data Science Capstone Project
# ####

# %% [markdown]
# ## 1. Importing all Necessary Libraries

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
from bs4 import BeautifulSoup 
import requests
from geopy.geocoders import Nominatim
import folium
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #
# ## 2. Importing Hospital Admission Dataset

# %%
hospital = pd.read_excel('hospital.xls')
hospital = hospital.iloc[14:,:]
hospital = hospital.iloc[1:,1:8]
#hospital.head()
hospital = hospital.reset_index().drop(['index'], axis = 1)
hospital.drop(['Unnamed: 2', 'Unnamed: 3'], axis = 1, inplace = True)
hospital.columns = ['Neighbourhood', 'Population', 'Male Admission', 'Female Admission', 'Both Admission']

#hospital['Neighbourhood'] = hospital['Neighbourhood'].str.replace('-', ' ')
#test.head(20)

hospital.head()
# Out:
#                        Neighbourhood Population Male Admission  \
# 0             West Humber-Clairville      34080           2453
# 1  Mount Olive-Silverstone-Jamestown      32675           2256
# 2       Thistletown-Beaumond Heights      10140            953
# 3                    Rexdale-Kipling      10455            938
# 4                   Elms-Old Rexdale       9970            674
#
#   Female Admission Both Admission
# 0             3151           5604
# 1             3004           5260
# 2             1153           2106
# 3             1090           2028
# 4              978           1652

# %% [markdown]
# #
# ## 3. Integrating Neighborhoods with their respective Locations

# %%
T_lat = []
T_log = []
for index, row in hospital.iterrows():
    neighbor = row['Neighbourhood']
    address = '{}, Toronto, ON, Canada'.format(neighbor)
    geolocator = Nominatim(user_agent = 'to_explorer')
    location = geolocator.geocode(address)
    if location is None:
        #pass
        T_lat.append(np.nan)
        T_log.append(np.nan)
        print('{} location not found'.format(row['Neighbourhood']))
    else:
        T_lat.append(location.latitude)
        T_log.append(location.longitude)
        print('{} location is {}, {}'.format(row['Neighbourhood'], location.latitude, location.longitude))
# Out:
# West Humber-Clairville location is 43.72337025, -79.59745741095173
# Mount Olive-Silverstone-Jamestown location not found
# Thistletown-Beaumond Heights location not found
# Rexdale-Kipling location is 43.722114149999996, -79.57229244708017
# Elms-Old Rexdale location is 43.72176985, -79.55217331972301
# Kingsview Village-The Westway location not found
# Willowridge-Martingrove-Richview location not found
# Humber Heights-Westmount location is 43.6957852, -79.5208324
# Edenbridge-Humber Valley location is 43.670672, -79.5188545
# Princess-Rosethorn location not found
# Eringate-Centennial-West Deane location not found
# Markland Wood location is 43.63123865, -79.58543401986114
# Etobicoke West Mall location is 43.6435491, -79.56532534553605
# Islington-City Centre West location is 43.6625768, -79.5317888
# Kingsway South location is 43.6473811, -79.5113328
# Stonegate-Queensway location not found
# Mimico location is 43.6166773, -79.4968048
# New Toronto location is 43.6007625, -79.505264
# Long Branch location is 43.59200455, -79.54536450659592
# Alderwood location is 43.6017173, -79.5452325
# Humber Summit location is 43.7600778, -79.5717598
# Humbermede location not found
# Pelmo Park-Humberlea location not found
# Black Creek location is 43.6954005, -79.485495
# Glenfield-Jane Heights location is 43.7567991, -79.5180495
# Downsview-Roding-CFB location not found
# York University Heights location is 43.7587808, -79.5194336
# Rustic location is 43.71336615, -79.50450373904313
# Maple Leaf location is 43.7122767, -79.4901977
# Brookhaven-Amesbury location not found
# Yorkdale-Glen Park location is 43.703434, -79.45291835752212
# Englemount-Lawrence location is 43.7172222, -79.4382909
# Clanton Park location not found
# Bathurst Manor location is 43.76389295, -79.45636693710946
# Westminster-Branson location not found
# Newtonbrook West location is 43.795986, -79.4130896
# Willowdale West location is 43.7615095, -79.4109234
# Lansing-Westgate location is 43.7589503, -79.4225555
# Bedford Park-Nortown location not found
# St.Andrew-Windfields location is 43.6477917, -79.3848711
# Bridle Path-Sunnybrook-York Mills location not found
# Banbury-Don Mills location is 43.7526832, -79.3652703
# Victoria Village location is 43.732658, -79.3111892
# Flemingdon Park location is 43.7184315, -79.333204
# Parkwoods-Donalda location not found
# Pleasant View location is 43.787048, -79.3337137
# Don Valley Village location is 43.7926732, -79.3547219
# Hillcrest Village location is 43.6816953, -79.4257118
# Bayview Woods-Steeles location is 43.7981268, -79.3829726
# Newtonbrook East location is 43.795986, -79.4130896
# Willowdale East location is 43.7615095, -79.4109234
# Bayview Village location is 43.7691966, -79.3766617
# Henry Farm location is 43.7695089, -79.354296
# O'Connor-Parkview location is 43.7023902, -79.3160976
# Thorncliffe Park location is 43.704553, -79.3454074
# Leaside-Bennington location is 43.7014812, -79.3731559
# Broadview North location is 43.6839216, -79.3569421
# Old East York location is 43.712452, -79.31265325
# Danforth-East York location is 43.6881713, -79.3018156
# Woodbine-Lumsden location not found
# Taylor-Massey location is 43.7240387, -79.2661943
# East End-Danforth location is 43.6684402, -79.33067
# The Beaches location is 43.6710244, -79.296712
# Woodbine Corridor location not found
# Greenwood-Coxwell location not found
# Danforth location is 43.6864333, -79.3003555
# Playter Estates-Danforth location is 43.6786661, -79.3555177
# North Riverdale location is 43.66064985, -79.34271760826113
# Blake-Jones location not found
# South Riverdale location is 43.66064985, -79.34271760826113
# Cabbagetown-South St. James Town location not found
# Regent Park location is 43.6607056, -79.3604569
# Moss Park location is 43.6546438, -79.3697278
# North St. James Town location not found
# Church-Yonge Corridor location is 43.6730826, -79.38828915261209
# Bay Street Corridor location is 43.6688649, -79.3891256
# Waterfront Communities-The Island location not found
# Kensington-Chinatown location not found
# University location is 43.663461999999996, -79.39775965337452
# Palmerston-Little Italy location is 43.6610934, -79.4122283
# Trinity-Bellwoods location is 43.64756465, -79.41388090266673
# Niagara location is 43.6440753, -79.4086982
# Dufferin Grove location is 43.6536319, -79.4264389
# Little Portugal location is 43.64741325, -79.43111632546047
# South Parkdale location is 43.6447523, -79.4482598
# Roncesvalles location is 43.6514426, -79.4510381
# High Park-Swansea location is 43.6495416, -79.4842102
# High Park North location is 43.6573833, -79.470961
# Runnymede-Bloor West Village location is 43.6517776, -79.4759227
# Junction Area location not found
# Weston-Pellam Park location not found
# Corso Italia-Davenport location is 43.677954, -79.4430828
# Dovercourt-Wallace Emerson-Junction location is 43.668005, -79.4413386
# Wychwood location is 43.682121699999996, -79.42383883756801
# Annex location is 43.6703377, -79.407117
# Casa Loma location is 43.6781015, -79.409415775
# Yonge-St.Clair location is 43.6880777, -79.3943963721967
# Rosedale-Moore Park location is 43.6869541, -79.3812804
# Mount Pleasant East location is 43.7039289, -79.3881996
# Yonge-Eglinton location is 43.7067479, -79.3983271
# Forest Hill South location is 43.6935586, -79.4139023
# Forest Hill North location is 43.6935586, -79.4139023
# Lawrence Park South location is 43.729199, -79.4032525
# Mount Pleasant West location is 43.7084166, -79.3901348
# Lawrence Park North location is 43.729199, -79.4032525
# Humewood-Cedarvale location is 43.6883215, -79.4280805
# Oakwood Village location is 43.6827255, -79.4380548
# Briar Hill - Belgravia location not found
# Caledonia-Fairbank location not found
# Keelesdale-Eglinton West location is 43.6901578, -79.4749985
# Rockcliffe-Smythe location not found
# Beechborough-Greenbrook location not found
# Weston location is 43.7001608, -79.5162474
# Lambton Baby Point location not found
# Mount Dennis location is 43.6869597, -79.4895513
# Steeles location is 43.8161778, -79.3145378
# L'Amoreaux location is 43.799003, -79.3059669
# Tam O'Shanter-Sullivan location is 43.7792808, -79.3036989
# Wexford/Maryvale location not found
# Clairlea-Birchmount location not found
# Oakridge location is 43.6971738, -79.2748232
# Birchcliffe-Cliffside location not found
# Cliffcrest location is 43.7218363, -79.2362138
# Kennedy Park location is 43.724878, -79.2539688
# Ionview location is 43.7359904, -79.2765146
# Dorset Park location is 43.7528467, -79.282067
# Bendale location is 43.7535196, -79.2553355
# Agincourt South-Malvern West location not found
# Agincourt North location is 43.8080383, -79.2664391
# Milliken location is 43.8231743, -79.3017626
# Rouge location is 43.8049304, -79.1658374
# Malvern location is 43.8091955, -79.2217008
# Centennial Scarborough location is 43.7874914, -79.1507681
# Highland Creek location is 43.7901172, -79.1733344
# Morningside location is 43.7826012, -79.2049579
# West Hill location is 43.7689144, -79.1872905
# Woburn location is 43.7598243, -79.2252908
# Eglinton East location is 43.7394646, -79.2320997
# Scarborough Village location is 43.7437422, -79.2116324
# Guildwood location is 43.7552251, -79.1982293
# nan location is 43.643429850000004, -79.37905948373245
# nan location is 43.643429850000004, -79.37905948373245

# %%
hospital['Latitudes'] = T_lat
hospital['Longitudes'] = T_log
hospital.head(10)
# Out:
#                        Neighbourhood Population Male Admission  \
# 0             West Humber-Clairville      34080           2453
# 1  Mount Olive-Silverstone-Jamestown      32675           2256
# 2       Thistletown-Beaumond Heights      10140            953
# 3                    Rexdale-Kipling      10455            938
# 4                   Elms-Old Rexdale       9970            674
# 5      Kingsview Village-The Westway      21585           1713
# 6   Willowridge-Martingrove-Richview      21310           1689
# 7           Humber Heights-Westmount      10600            950
# 8           Edenbridge-Humber Valley      14895           1029
# 9                 Princess-Rosethorn      11200            708
#
#   Female Admission Both Admission  Latitudes  Longitudes
# 0             3151           5604  43.723370  -79.597457
# 1             3004           5260        NaN         NaN
# 2             1153           2106        NaN         NaN
# 3             1090           2028  43.722114  -79.572292
# 4              978           1652  43.721770  -79.552173
# 5             2253           3966        NaN         NaN
# 6             2211           3900        NaN         NaN
# 7             1335           2285  43.695785  -79.520832
# 8             1269           2298  43.670672  -79.518855
# 9              865           1573        NaN         NaN

# %%
hospital.dropna(inplace = True, axis = 0)
hospital.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105 entries, 0 to 139
# Data columns (total 7 columns):
# Neighbourhood       105 non-null object
# Population          105 non-null object
# Male Admission      105 non-null object
# Female Admission    105 non-null object
# Both Admission      105 non-null object
# Latitudes           105 non-null float64
# Longitudes          105 non-null float64
# dtypes: float64(2), object(5)
# memory usage: 6.6+ KB

# %%
hospital.head()
# Out:
#               Neighbourhood Population Male Admission Female Admission  \
# 0    West Humber-Clairville      34080           2453             3151
# 3           Rexdale-Kipling      10455            938             1090
# 4          Elms-Old Rexdale       9970            674              978
# 7  Humber Heights-Westmount      10600            950             1335
# 8  Edenbridge-Humber Valley      14895           1029             1269
#
#   Both Admission  Latitudes  Longitudes
# 0           5604  43.723370  -79.597457
# 3           2028  43.722114  -79.572292
# 4           1652  43.721770  -79.552173
# 7           2285  43.695785  -79.520832
# 8           2298  43.670672  -79.518855

# %% [markdown]
# #
# ## 4. Scraping the Income Sets

# %%
url = 'https://www03.cmhc-schl.gc.ca/hmip-pimh/en/TableMapChart/TableMatchingCriteria?GeographyType=MetropolitanMajorArea&GeographyId=2270&CategoryLevel1=Population%2C%20Households%20and%20Housing%20Stock&CategoryLevel2=Household%20Income&ColumnField=HouseholdIncomeRange&RowField=Neighbourhood&SearchTags%5B0%5D.Key=Households&SearchTags%5B0%5D.Value=Number&SearchTags%5B1%5D.Key=Statistics&SearchTags%5B1%5D.Value=AverageAndMedian'
r = requests.get(url).text
soup = BeautifulSoup(r)

# %%
Neighbourhood = []
Income = []
table =soup.find(class_ = 'CawdDataTable')
table = table.tbody
table = table.find_all('tr')
#print(table)
for row in table:
    #print(row)
    row_list = row.text.strip().split('\n')
    #print(row_list)
    Neighbourhood.append(row_list[0])
    Income.append(row_list[3].replace(',', ''))
    
ni_dict = {'Neighbourhood': Neighbourhood, 'Income': Income}
NI_df = pd.DataFrame(ni_dict)
NI_df.head(10)
# Out:
#                              Neighbourhood  Income
# 0                        Agincourt/Malvern   71025
# 1                           Ajax/Pickering   94805
# 2                                Alderwood   84163
# 3                                   Aurora  113594
# 4             Banbury-Don Mills/York Mills  168106
# 5                           Bathurst Manor   79185
# 6                      Bay Street Corridor   65786
# 7                          Bayview Village   76983
# 8  Bayview Woods-Steeles/Hillcrest Village   79794
# 9                     Bedford Park-Nortown  175773

# %% [markdown]
# #
# ## 5. Merging Neighborhoods and their Income (Left Join)

# %%
df = pd.merge(hospital, NI_df,on='Neighbourhood', how = 'left')

# %%
df['Income'] = df['Income'].astype(float)
df.head(10)
# Out:
#                 Neighbourhood Population Male Admission Female Admission  \
# 0      West Humber-Clairville      34080           2453             3151
# 1             Rexdale-Kipling      10455            938             1090
# 2            Elms-Old Rexdale       9970            674              978
# 3    Humber Heights-Westmount      10600            950             1335
# 4    Edenbridge-Humber Valley      14895           1029             1269
# 5               Markland Wood      10395            804              944
# 6         Etobicoke West Mall      11005            821             1058
# 7  Islington-City Centre West      38130           2829             3966
# 8              Kingsway South       9170            607              745
# 9                      Mimico      26635           1758             2080
#
#   Both Admission  Latitudes  Longitudes    Income
# 0           5604  43.723370  -79.597457   71699.0
# 1           2028  43.722114  -79.572292   64800.0
# 2           1652  43.721770  -79.552173   63156.0
# 3           2285  43.695785  -79.520832   76669.0
# 4           2298  43.670672  -79.518855  144418.0
# 5           1748  43.631239  -79.585434       NaN
# 6           1879  43.643549  -79.565325   80527.0
# 7           6795  43.662577  -79.531789       NaN
# 8           1352  43.647381  -79.511333  198998.0
# 9           3838  43.616677  -79.496805   71772.0

# %%
df[['Income']].describe().loc['25%',:]
# Out:
# Income    61907.0
# Name: 25%, dtype: float64

# %% [markdown]
# #
# ## 6. Exploring the Neighborhoods
# ### Connecting with Foursquare and explore nearby locations

# %%
CLIENT_ID = 'PJNJYWCFXQMKPTAHTRMWUGE3YMCVYDF5DM3JXCPEHFUHZJRV' # your Foursquare ID
CLIENT_SECRET = 'XUKXQKX21CULKQXCPD3D5CDEVIM4COJBMDWBJY2ZH0PFKYEA' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=1000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)  


# calling functions
toronto_venues = getNearbyVenues(names = df['Neighbourhood'],
                                 latitudes = df['Latitudes'],
                                 longitudes = df['Longitudes'])
# Out:
# West Humber-Clairville
# Rexdale-Kipling
# Elms-Old Rexdale
# Humber Heights-Westmount
# Edenbridge-Humber Valley
# Markland Wood
# Etobicoke West Mall
# Islington-City Centre West
# Kingsway South
# Mimico
# New Toronto
# Long Branch
# Alderwood
# Humber Summit
# Black Creek
# Glenfield-Jane Heights
# York University Heights
# Rustic
# Maple Leaf
# Yorkdale-Glen Park
# Englemount-Lawrence
# Bathurst Manor
# Newtonbrook West
# Willowdale West
# Lansing-Westgate
# St.Andrew-Windfields
# Banbury-Don Mills
# Victoria Village
# Flemingdon Park
# Pleasant View
# Don Valley Village
# Hillcrest Village
# Bayview Woods-Steeles
# Newtonbrook East
# Willowdale East
# Bayview Village
# Henry Farm
# O'Connor-Parkview
# Thorncliffe Park
# Leaside-Bennington
# Broadview North
# Old East York
# Danforth-East York
# Taylor-Massey
# East End-Danforth
# The Beaches
# Danforth
# Playter Estates-Danforth
# North Riverdale
# South Riverdale
# Regent Park
# Moss Park
# Church-Yonge Corridor
# Bay Street Corridor
# University
# Palmerston-Little Italy
# Trinity-Bellwoods
# Niagara
# Dufferin Grove
# Little Portugal
# South Parkdale
# Roncesvalles
# High Park-Swansea
# High Park North
# Runnymede-Bloor West Village
# Corso Italia-Davenport
# Dovercourt-Wallace Emerson-Junction
# Wychwood
# Annex
# Casa Loma
# Yonge-St.Clair
# Rosedale-Moore Park
# Mount Pleasant East
# Yonge-Eglinton
# Forest Hill South
# Forest Hill North
# Lawrence Park South
# Mount Pleasant West
# Lawrence Park North
# Humewood-Cedarvale
# Oakwood Village
# Keelesdale-Eglinton West
# Weston
# Mount Dennis
# Steeles
# L'Amoreaux
# Tam O'Shanter-Sullivan
# Oakridge
# Cliffcrest
# Kennedy Park
# Ionview
# Dorset Park
# Bendale
# Agincourt North
# Milliken
# Rouge
# Malvern
# Centennial Scarborough
# Highland Creek
# Morningside
# West Hill
# Woburn
# Eglinton East
# Scarborough Village
# Guildwood

# %%
toronto_venues.head(10)
# Out:
#              Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  West Humber-Clairville               43.72337              -79.597457
# 1  West Humber-Clairville               43.72337              -79.597457
# 2  West Humber-Clairville               43.72337              -79.597457
# 3  West Humber-Clairville               43.72337              -79.597457
# 4  West Humber-Clairville               43.72337              -79.597457
# 5  West Humber-Clairville               43.72337              -79.597457
# 6  West Humber-Clairville               43.72337              -79.597457
# 7  West Humber-Clairville               43.72337              -79.597457
# 8  West Humber-Clairville               43.72337              -79.597457
# 9  West Humber-Clairville               43.72337              -79.597457
#
#                               Venue  Venue Latitude  Venue Longitude  \
# 0                          Fortinos       43.721438       -79.596291
# 1                   Mandarin Buffet       43.720360       -79.594387
# 2                  Humber Arboretum       43.724653       -79.608006
# 3                         Bulk Barn       43.720290       -79.600887
# 4  New York Fries - Woodbine Centre       43.720568       -79.599609
# 5                   TD Canada Trust       43.719630       -79.599896
# 6                           Winners       43.719819       -79.594923
# 7                Woodbine Racetrack       43.716673       -79.604962
# 8                           Xawaash       43.715786       -79.593053
# 9                       Dairy Queen       43.730244       -79.601391
#
#              Venue Category
# 0             Grocery Store
# 1        Chinese Restaurant
# 2                    Garden
# 3         Food & Drink Shop
# 4                Restaurant
# 5                      Bank
# 6          Department Store
# 7                Racecourse
# 8  Mediterranean Restaurant
# 9            Ice Cream Shop

# %%
toronto_pharmacy = toronto_venues[toronto_venues['Venue Category'] == 'Pharmacy'].reset_index().drop('index', axis = 1)
toronto_pharmacy.head()
# Out:
#                  Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0    Humber Heights-Westmount              43.695785              -79.520832
# 1    Edenbridge-Humber Valley              43.670672              -79.518855
# 2         Etobicoke West Mall              43.643549              -79.565325
# 3  Islington-City Centre West              43.662577              -79.531789
# 4  Islington-City Centre West              43.662577              -79.531789
#
#                    Venue  Venue Latitude  Venue Longitude Venue Category
# 0     Shoppers Drug Mart       43.701264       -79.519705       Pharmacy
# 1     Shoppers Drug Mart       43.661721       -79.518881       Pharmacy
# 2     Shoppers Drug Mart       43.641312       -79.576924       Pharmacy
# 3     Shoppers Drug Mart       43.663067       -79.531753       Pharmacy
# 4  Thorncrest Drug Store       43.662988       -79.531817       Pharmacy

# %%
toronto_pharmacy.head(10)
# Out:
#                  Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0    Humber Heights-Westmount              43.695785              -79.520832
# 1    Edenbridge-Humber Valley              43.670672              -79.518855
# 2         Etobicoke West Mall              43.643549              -79.565325
# 3  Islington-City Centre West              43.662577              -79.531789
# 4  Islington-City Centre West              43.662577              -79.531789
# 5              Kingsway South              43.647381              -79.511333
# 6                 New Toronto              43.600763              -79.505264
# 7                 Long Branch              43.592005              -79.545365
# 8                   Alderwood              43.601717              -79.545232
# 9      Glenfield-Jane Heights              43.756799              -79.518050
#
#                    Venue  Venue Latitude  Venue Longitude Venue Category
# 0     Shoppers Drug Mart       43.701264       -79.519705       Pharmacy
# 1     Shoppers Drug Mart       43.661721       -79.518881       Pharmacy
# 2     Shoppers Drug Mart       43.641312       -79.576924       Pharmacy
# 3     Shoppers Drug Mart       43.663067       -79.531753       Pharmacy
# 4  Thorncrest Drug Store       43.662988       -79.531817       Pharmacy
# 5     Shoppers Drug Mart       43.647623       -79.510860       Pharmacy
# 6     Shoppers Drug Mart       43.601677       -79.502239       Pharmacy
# 7                 Rexall       43.593111       -79.538327       Pharmacy
# 8       Sav-On Drug Mart       43.609891       -79.549618       Pharmacy
# 9     Shoppers Drug Mart       43.756147       -79.515843       Pharmacy

# %% [markdown]
# ##### Getting the latitudes and longitudes of Toronto

# %%
address = 'Toronto, ON, Canada'
geolocator = Nominatim(user_agent = 'to_explorer')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geographical coordinates are {},{}'.format(latitude, longitude))
# Out:
# The geographical coordinates are 43.6534817,-79.3839347

# %%
my_map = folium.Map(location = [latitude, longitude], zoom_start=11)

for lat, lng, venue, neigh, in zip(toronto_pharmacy['Venue Latitude'], toronto_pharmacy['Venue Longitude'], toronto_pharmacy['Venue'], toronto_pharmacy['Neighborhood']):
    label = '{}, {}'.format(venue, neigh)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat,lng],
        radius = 5,
        popup= label,
        color = 'red',
        fill = True,
        fill_color = 'red',
        fill_opacity = 0.7,
        parse_html = False
    ).add_to(my_map)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_577f689a57d84616a97513d8af348cb5%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_577f689a57d84616a97513d8af348cb5%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_577f689a57d84616a97513d8af348cb5%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_577f689a57d84616a97513d8af348cb5%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## 7. Neighborhoods with most Pharmacy Shops

# %%
pharmacy_count = pd.DataFrame(toronto_pharmacy['Neighborhood'].value_counts())
pharmacy_count.columns = ['No. of Pharmacy']
pharmacy_count.head(10)
# Out:
#                                      No. of Pharmacy
# South Parkdale                                     3
# Dovercourt-Wallace Emerson-Junction                2
# York University Heights                            2
# Morningside                                        2
# Mount Pleasant East                                2
# Runnymede-Bloor West Village                       2
# Islington-City Centre West                         2
# Tam O'Shanter-Sullivan                             2
# Englemount-Lawrence                                2
# Willowdale East                                    2

# %% [markdown]
# #
# ## 8. Neighborhoods without Pharmacy Shops

# %%
pharma_neigh_set = set(toronto_pharmacy['Neighborhood'])
all_neigh = set(df['Neighbourhood'])
no_pharma_neigh  = all_neigh - pharma_neigh_set
neighbor_without_pharmacy = df[df['Neighbourhood'].isin(no_pharma_neigh)]
neighbor_without_pharmacy.head()
# Out:
#             Neighbourhood Population Male Admission Female Admission  \
# 0  West Humber-Clairville      34080           2453             3151
# 1         Rexdale-Kipling      10455            938             1090
# 2        Elms-Old Rexdale       9970            674              978
# 5           Markland Wood      10395            804              944
# 9                  Mimico      26635           1758             2080
#
#   Both Admission  Latitudes  Longitudes   Income
# 0           5604  43.723370  -79.597457  71699.0
# 1           2028  43.722114  -79.572292  64800.0
# 2           1652  43.721770  -79.552173  63156.0
# 5           1748  43.631239  -79.585434      NaN
# 9           3838  43.616677  -79.496805  71772.0

# %%
map_without_pharma = folium.Map(location = [latitude, longitude], zoom_start=11)

for lat, lng, neigh, in zip(neighbor_without_pharmacy['Latitudes'], neighbor_without_pharmacy['Longitudes'], neighbor_without_pharmacy['Neighbourhood']):
    label = '{}'.format(neigh)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat,lng],
        radius = 5,
        popup= label,
        color = 'green',
        fill = True,
        fill_color = 'green',
        fill_opacity = 0.7,
        parse_html = False
    ).add_to(map_without_pharma)
map_without_pharma
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_267ce6d0570b4f718a52472d11af3986%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_267ce6d0570b4f718a52472d11af3986%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_267ce6d0570b4f718a52472d11af3986%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_267ce6d0570b4f718a52472d11af3986%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# #
# ## 9. Neighborhoods with Pharmacy Shops

# %%
neighbor_with_pharmacy = df[df['Neighbourhood'].isin(pharma_neigh_set)]
neighbor_with_pharmacy.head()
# Out:
#                 Neighbourhood Population Male Admission Female Admission  \
# 3    Humber Heights-Westmount      10600            950             1335
# 4    Edenbridge-Humber Valley      14895           1029             1269
# 6         Etobicoke West Mall      11005            821             1058
# 7  Islington-City Centre West      38130           2829             3966
# 8              Kingsway South       9170            607              745
#
#   Both Admission  Latitudes  Longitudes    Income
# 3           2285  43.695785  -79.520832   76669.0
# 4           2298  43.670672  -79.518855  144418.0
# 6           1879  43.643549  -79.565325   80527.0
# 7           6795  43.662577  -79.531789       NaN
# 8           1352  43.647381  -79.511333  198998.0

# %% [markdown]
# #### Pharmacies and Neighborhoods without pharmacy

# %%
map_with_out_pharma = folium.Map(location = [latitude, longitude], zoom_start=11)

for lat, lng, venue, neigh, in zip(toronto_pharmacy['Venue Latitude'], toronto_pharmacy['Venue Longitude'], toronto_pharmacy['Venue'], toronto_pharmacy['Neighborhood']):
    label = '{}, {}'.format(venue, neigh)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat,lng],
        radius = 5,
        popup= label,
        color = 'red',
        fill = True,
        fill_color = 'red',
        fill_opacity = 0.7,
        parse_html = False
    ).add_to(map_with_out_pharma)

for lat, lng, neigh, in zip(neighbor_without_pharmacy['Latitudes'], neighbor_without_pharmacy['Longitudes'], neighbor_without_pharmacy['Neighbourhood']):
    label = '{}'.format(neigh)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat,lng],
        radius = 5,
        popup= label,
        color = 'green',
        fill = True,
        fill_color = 'green',
        fill_opacity = 0.7,
        parse_html = False
    ).add_to(map_with_out_pharma)

map_with_out_pharma
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_99d4c8ea45164656a29b2f304bae2a74%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_99d4c8ea45164656a29b2f304bae2a74%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_99d4c8ea45164656a29b2f304bae2a74%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_99d4c8ea45164656a29b2f304bae2a74%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## 10. Hospitals in Toronto

# %%
address = 'Baycrest Health Sciences, Toronto, ON, Canada'
geolocator = Nominatim(user_agent = 'to_explorer')
location = geolocator.geocode(address)
l1 = location.latitude
l2 = location.longitude
print('The geographical coordinates are {},{}'.format(l1, l2))
# Out:
# The geographical coordinates are 43.7302646,-79.43409194469027

# %% [markdown]
# ### Scraping for the names of Hospitals in Toronto Ontario

# %%
name_list = []

h_url = 'https://en.wikipedia.org/wiki/List_of_hospitals_in_Toronto'
rq = requests.get(h_url).text
soup = BeautifulSoup(rq)
table = soup.find_all('table')
table = table[0]
table = table.find_all('tr')[1:]
for name in table:
    name_list.append(name.find('td').text)

# %%
h_lat = []
h_lng = []
for name in name_list:
    address = '{}, Toronto, ON, Canada'.format(name)
    geolocator = Nominatim(user_agent = 'to_explorer')
    location = geolocator.geocode(address)
    if location is None:
        l1 = np.nan
        l2 = np.nan
    else:
        l1 = location.latitude
        l2 = location.longitude
    h_lat.append(l1)
    h_lng.append(l2)
    print('{} geographical coordinates are {},{}'.format(name, l1, l2))
    
hos_dict = {'Hospital Name': name_list, 'Hospital Latitide': h_lat, 'Hospital Longitude': h_lng}
hospital_df = pd.DataFrame(hos_dict)
hospital_df.head()
# Out:
# Baycrest Health Sciences geographical coordinates are 43.7302646,-79.43409194469027
# Bellwood Health Services geographical coordinates are nan,nan
# Bridgepoint Active Healthcare geographical coordinates are 43.666546350000004,-79.35458007170948
# Casey House geographical coordinates are 43.668927249999996,-79.37840347550002
# Centre for Addiction and Mental Health, College Street Site geographical coordinates are nan,nan
# Centre for Addiction and Mental Health, Queen Street Site geographical coordinates are nan,nan
# Centre for Addiction and Mental Health, Russell Street Site geographical coordinates are nan,nan
# Centric Health Surgical Centre Toronto geographical coordinates are nan,nan
# Etobicoke General Hospital geographical coordinates are 43.7290756,-79.59788584813774
# Holland Bloorview Kids Rehabilitation Hospital geographical coordinates are 43.7184671,-79.37347984846242
# Hospital for Sick Children geographical coordinates are 43.657371749999996,-79.38760057839349
# Humber River Hospital, Wilson Site geographical coordinates are nan,nan
# Michael Garron Hospital geographical coordinates are 43.689953200000005,-79.32493147310899
# Mount Sinai Hospital geographical coordinates are 43.657443650000005,-79.39033976650668
# North York General Hospital geographical coordinates are 43.7692285,-79.3625576854712
# North York General Hospital, Branson Centre geographical coordinates are nan,nan
# North York General Hospital, Seniors' Health Centre geographical coordinates are nan,nan
# Princess Margaret Cancer Centre geographical coordinates are nan,nan
# Providence Healthcare geographical coordinates are 43.71225565,-79.28498203321067
# Queensway Health Centre geographical coordinates are 43.6099866,-79.56272346216254
# Centenary Hospital geographical coordinates are 43.7810872,-79.2054395625573
# Runnymede Healthcare Centre geographical coordinates are 43.6646911,-79.48098788916948
# Scarborough General Hospital geographical coordinates are nan,nan
# Birchmount Hospital geographical coordinates are 43.7728641,-79.2917074
# St. Joseph's Health Centre geographical coordinates are 43.6403905,-79.45014220870584
# St. Michael's Hospital geographical coordinates are 43.6536408,-79.37780684414469
# Sunnybrook Health Sciences Centre geographical coordinates are nan,nan
# Sunnybrook Holland Centre geographical coordinates are 43.66509705,-79.38229271448823
# St. John's Rehab Hospital geographical coordinates are nan,nan
# Toronto General Hospital geographical coordinates are 43.658587600000004,-79.38815803478147
# Toronto Grace Health Centre geographical coordinates are nan,nan
# Toronto Rehabilitation Institute: Bickle Centre, Lakeside Centre, Lyndhust Centre, Rumsey Centre - Cardiac / Neuro, University Centre geographical coordinates are nan,nan
# Toronto Western Hospital geographical coordinates are 43.653566999999995,-79.40549604487205
# West Park Healthcare Centre geographical coordinates are 43.68888365,-79.50843980975665
# Women's College Hospital geographical coordinates are 43.661733999999996,-79.38754180202815
#                                        Hospital Name  Hospital Latitide  \
# 0                           Baycrest Health Sciences          43.730265
# 1                           Bellwood Health Services                NaN
# 2                      Bridgepoint Active Healthcare          43.666546
# 3                                        Casey House          43.668927
# 4  Centre for Addiction and Mental Health, Colleg...                NaN
#
#    Hospital Longitude
# 0          -79.434092
# 1                 NaN
# 2          -79.354580
# 3          -79.378403
# 4                 NaN

# %%
# Bellwood Health Serivces
hospital_df.iloc[1,1] = 43.719979509908484
hospital_df.iloc[1,2] = -79.36652390739894

# Centre for Addiction and Mental Health, Queen
hospital_df.iloc[5,1] = 43.64288627678428
hospital_df.iloc[5,2] = -79.41843106439363

# Centric Health Surgical Centre Toronto
hospital_df.iloc[7,1] = 43.72405433696723
hospital_df.iloc[7,2] = -79.3361659227796

# Humber River Hospital, Wilson Site
hospital_df.iloc[11,1] = 43.724125146526454
hospital_df.iloc[11,2] = -79.48818348653575

# North York General Hospital, Branson Centre
hospital_df.iloc[15,1] = 43.77240828098524 
hospital_df.iloc[15,2] = -79.44746924602813

# North York General Hospital, Seniors' Health Care Center
hospital_df.iloc[16,1] = 43.77311766153121
hospital_df.iloc[16,2] = -79.35992902884257

# Princess Margaret Cancer Centre	
hospital_df.iloc[17,1] = 43.65838892886005
hospital_df.iloc[17,2] = -79.39060403104092

# Scarborough General Hospital	
hospital_df.iloc[22,1] = 43.75637626665658
hospital_df.iloc[22,2] = -79.2468913310374

# Sunnybrook Health Sciences Centre	
hospital_df.iloc[26,1] = 43.72291120820059
hospital_df.iloc[26,2] = -79.37296965987429

# St. John's Rehab Hospital
hospital_df.iloc[28,1] = 43.78764260322017
hospital_df.iloc[28,2] = -79.40396037336495

# Toronto Grace Health Centre
hospital_df.iloc[30,1] = 43.67058427072321
hospital_df.iloc[30,2] = -79.38314054453343

# Toronto Rehabilitation Institute: Bickle Centr
hospital_df.iloc[31,1] = 'Toronto Rehabilitation Institute'
hospital_df.iloc[31,1] = 43.65681112810011
hospital_df.iloc[31,2] = -79.38979507115174

hospital_df.head(40)
# Out:
#                                         Hospital Name Hospital Latitide  \
# 0                            Baycrest Health Sciences           43.7303
# 1                            Bellwood Health Services             43.72
# 2                       Bridgepoint Active Healthcare           43.6665
# 3                                         Casey House           43.6689
# 4   Centre for Addiction and Mental Health, Colleg...               NaN
# 5   Centre for Addiction and Mental Health, Queen ...           43.6429
# 6   Centre for Addiction and Mental Health, Russel...               NaN
# 7              Centric Health Surgical Centre Toronto           43.7241
# 8                          Etobicoke General Hospital           43.7291
# 9      Holland Bloorview Kids Rehabilitation Hospital           43.7185
# 10                         Hospital for Sick Children           43.6574
# 11                 Humber River Hospital, Wilson Site           43.7241
# 12                            Michael Garron Hospital             43.69
# 13                               Mount Sinai Hospital           43.6574
# 14                        North York General Hospital           43.7692
# 15        North York General Hospital, Branson Centre           43.7724
# 16  North York General Hospital, Seniors' Health C...           43.7731
# 17                    Princess Margaret Cancer Centre           43.6584
# 18                              Providence Healthcare           43.7123
# 19                            Queensway Health Centre             43.61
# 20                                 Centenary Hospital           43.7811
# 21                        Runnymede Healthcare Centre           43.6647
# 22                       Scarborough General Hospital           43.7564
# 23                                Birchmount Hospital           43.7729
# 24                         St. Joseph's Health Centre           43.6404
# 25                             St. Michael's Hospital           43.6536
# 26                  Sunnybrook Health Sciences Centre           43.7229
# 27                          Sunnybrook Holland Centre           43.6651
# 28                          St. John's Rehab Hospital           43.7876
# 29                           Toronto General Hospital           43.6586
# 30                        Toronto Grace Health Centre           43.6706
# 31  Toronto Rehabilitation Institute: Bickle Centr...           43.6568
# 32                           Toronto Western Hospital           43.6536
# 33                        West Park Healthcare Centre           43.6889
# 34                           Women's College Hospital           43.6617
#
#     Hospital Longitude
# 0           -79.434092
# 1           -79.366524
# 2           -79.354580
# 3           -79.378403
# 4                  NaN
# 5           -79.418431
# 6                  NaN
# 7           -79.336166
# 8           -79.597886
# 9           -79.373480
# 10          -79.387601
# 11          -79.488183
# 12          -79.324931
# 13          -79.390340
# 14          -79.362558
# 15          -79.447469
# 16          -79.359929
# 17          -79.390604
# 18          -79.284982
# 19          -79.562723
# 20          -79.205440
# 21          -79.480988
# 22          -79.246891
# 23          -79.291707
# 24          -79.450142
# 25          -79.377807
# 26          -79.372970
# 27          -79.382293
# 28          -79.403960
# 29          -79.388158
# 30          -79.383141
# 31          -79.389795
# 32          -79.405496
# 33          -79.508440
# 34          -79.387542

# %%
hospital_df.dropna(inplace = True, axis = 0)
hospital_df.head()
# Out:
#                                        Hospital Name Hospital Latitide  \
# 0                           Baycrest Health Sciences           43.7303
# 1                           Bellwood Health Services             43.72
# 2                      Bridgepoint Active Healthcare           43.6665
# 3                                        Casey House           43.6689
# 5  Centre for Addiction and Mental Health, Queen ...           43.6429
#
#    Hospital Longitude
# 0          -79.434092
# 1          -79.366524
# 2          -79.354580
# 3          -79.378403
# 5          -79.418431

# %% [markdown]
# #
# ## Map Visualizations
# #

# %% [markdown]
# ## 11. Visualizing the Neighborhoods, Pharmacies, and Major Hospitals of Toronto

# %% [markdown]
# ###
# we visualize all the pharmacies in Toronto area, Neighborhoods without Pharmacies and the major Hospitals of the Toronto City

# %%
map_with_out_pharma = folium.Map(location = [latitude, longitude], zoom_start=11)

for lat, lng, venue, neigh, in zip(toronto_pharmacy['Venue Latitude'], toronto_pharmacy['Venue Longitude'], toronto_pharmacy['Venue'], toronto_pharmacy['Neighborhood']):
    label = '{}, {}'.format(venue, neigh)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat,lng],
        radius = 5,
        popup= label,
        color = 'red',
        fill = True,
        fill_color = 'red',
        fill_opacity = 0.7,
        parse_html = False
    ).add_to(map_with_out_pharma)

for lat, lng, neigh, in zip(neighbor_without_pharmacy['Latitudes'], neighbor_without_pharmacy['Longitudes'], neighbor_without_pharmacy['Neighbourhood']):
    label = '{}'.format(neigh)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat,lng],
        radius = 5,
        popup= label,
        color = 'green',
        fill = True,
        fill_color = 'green',
        fill_opacity = 0.7,
        parse_html = False
    ).add_to(map_with_out_pharma)

    
for lat, lng, name, in zip(hospital_df['Hospital Latitide'], hospital_df['Hospital Longitude'], hospital_df['Hospital Name']):
    label = '{}'.format(name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat,lng],
        radius = 10,
        popup= label,
        color = 'blue',
        fill = True,
        fill_color = 'blue',
        fill_opacity = 0.7,
        parse_html = False
    ).add_to(map_with_out_pharma)

print('Red Circle: Pharmacy Shops')
print('Green Circle: Neighborhoods without Pharmacies')
print('Blue Circle: Major Hospitals')
map_with_out_pharma
# Out:
# Red Circle: Pharmacy Shops
# Green Circle: Neighborhoods without Pharmacies
# Blue Circle: Major Hospitals
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_33f73e148dcf4827b66d250bf6e8adf4%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_33f73e148dcf4827b66d250bf6e8adf4%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_33f73e148dcf4827b66d250bf6e8adf4%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_33f73e148dcf4827b66d250bf6e8adf4%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## 12. Narrowing Down our results

# %%
admission20 = neighbor_without_pharmacy.sort_values('Both Admission', ascending = False).head(20).reset_index().drop('index', axis=1)
admission20.head()
# Out:
#             Neighbourhood Population Male Admission Female Admission  \
# 0  West Humber-Clairville      34080           2453             3151
# 1                   Annex      28615           2009             2487
# 2         South Riverdale      25615           1886             2535
# 3             Black Creek      22040           1659             2297
# 4                  Mimico      26635           1758             2080
#
#   Both Admission  Latitudes  Longitudes   Income
# 0           5604  43.723370  -79.597457  71699.0
# 1           4496  43.670338  -79.407117      NaN
# 2           4421  43.660650  -79.342718      NaN
# 3           3956  43.695400  -79.485495  57082.0
# 4           3838  43.616677  -79.496805  71772.0

# %%
map_admission10 = folium.Map(location = [latitude, longitude], zoom_start=11)

for lat, lng, name, in zip(hospital_df['Hospital Latitide'], hospital_df['Hospital Longitude'], hospital_df['Hospital Name']):
    label = '{}'.format(name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat,lng],
        radius = 10,
        popup= label,
        color = 'blue',
        fill = True,
        fill_color = 'blue',
        fill_opacity = 0.7,
        parse_html = False
    ).add_to(map_admission10)


for lat, lng, neigh, in zip(admission20['Latitudes'], admission20['Longitudes'], admission20['Neighbourhood']):
    label = '{}'.format(neigh)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat,lng],
        radius = 5,
        popup= label,
        color = 'green',
        fill = True,
        fill_color = 'green',
        fill_opacity = 0.7,
        parse_html = False
    ).add_to(map_admission10)

map_admission10
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a83dfddd77204da2925883002579af26%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a83dfddd77204da2925883002579af26%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a83dfddd77204da2925883002579af26%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a83dfddd77204da2925883002579af26%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
df.sort_values('Population', ascending = False).head(10).reset_index().drop('index', axis=1)
# Out:
#                          Neighbourhood Population Male Admission  \
# 0                               Woburn      53280           3337
# 1                                Rouge      45840           1277
# 2                              Malvern      44950           1888
# 3                           L'Amoreaux      44950           2710
# 4                      Willowdale East      44875           1323
# 5           Islington-City Centre West      38130           2829
# 6  Dovercourt-Wallace Emerson-Junction      34710           2273
# 7               West Humber-Clairville      34080           2453
# 8               Glenfield-Jane Heights      31430           2414
# 9                      Agincourt North      30310           1303
#
#   Female Admission Both Admission  Latitudes  Longitudes   Income
# 0             4652           7989  43.759824  -79.225291  62213.0
# 1             1918           3195  43.804930  -79.165837  97714.0
# 2             2728           4616  43.809196  -79.221701      NaN
# 3             3664           6374  43.799003  -79.305967      NaN
# 4             1942           3265  43.761510  -79.410923      NaN
# 5             3966           6795  43.662577  -79.531789      NaN
# 6             2773           5046  43.668005  -79.441339      NaN
# 7             3151           5604  43.723370  -79.597457  71699.0
# 8             3176           5590  43.756799  -79.518050      NaN
# 9             1754           3057  43.808038  -79.266439      NaN

# %%
admission5 = neighbor_without_pharmacy.sort_values('Both Admission', ascending = False).head(5).reset_index().drop('index', axis=1)
#admission.head()
map_admission5 = folium.Map(location = [latitude, longitude], zoom_start=11)

for lat, lng, name, in zip(hospital_df['Hospital Latitide'], hospital_df['Hospital Longitude'], hospital_df['Hospital Name']):
    label = '{}'.format(name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat,lng],
        radius = 2,
        popup= label,
        color = 'blue',
        fill = True,
        fill_color = 'blue',
        fill_opacity = 0.7,
        parse_html = False
    ).add_to(map_admission5)


for lat, lng, neigh, in zip(admission5['Latitudes'], admission5['Longitudes'], admission5['Neighbourhood']):
    label = '{}'.format(neigh)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat,lng],
        radius = 20,
        popup= label,
        color = 'green',
        fill = True,
        fill_color = 'green',
        fill_opacity = 0.7,
        parse_html = False
    ).add_to(map_admission5)

map_admission5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a67a43f7ef1c4ffe99a889df3acb9ed5%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a67a43f7ef1c4ffe99a889df3acb9ed5%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a67a43f7ef1c4ffe99a889df3acb9ed5%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a67a43f7ef1c4ffe99a889df3acb9ed5%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
admission5.head(5)
# Out:
#             Neighbourhood Population Male Admission Female Admission  \
# 0  West Humber-Clairville      34080           2453             3151
# 1                   Annex      28615           2009             2487
# 2         South Riverdale      25615           1886             2535
# 3             Black Creek      22040           1659             2297
# 4                  Mimico      26635           1758             2080
#
#   Both Admission  Latitudes  Longitudes   Income
# 0           5604  43.723370  -79.597457  71699.0
# 1           4496  43.670338  -79.407117      NaN
# 2           4421  43.660650  -79.342718      NaN
# 3           3956  43.695400  -79.485495  57082.0
# 4           3838  43.616677  -79.496805  71772.0

# %%
plt.bar(admission5['Neighbourhood'], admission5['Both Admission'], color = 'g')
plt.ylabel('No. of admissions')
plt.xticks(rotation= 90)
plt.style.use('fivethirtyeight')
plt.show()

# %%
plt.bar(admission5['Neighbourhood'], admission5['Both Admission'], color = 'r')
plt.ylabel('Population')
plt.xticks(rotation= 90)
plt.style.use('fivethirtyeight')
plt.show()
